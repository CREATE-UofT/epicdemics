# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns

# loading data 
f = open("Data/FID/README.md")
data = pd.read_csv("Data/FID/VIW_FID_EPI.csv")
# Out:
# /tmp/ipykernel_177491/289943900.py:8: DtypeWarning: Columns (28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Data/FID/VIW_FID_EPI.csv")

# %%
print(data.head(20))
# Out:
#    WHOREGION FLUSEASON HEMISPHERE          ITZ COUNTRY_CODE  \
# 0        AFR        NH         NH  FLU_NRT_AFR          DZA
# 1        AFR        NH         NH  FLU_NRT_AFR          DZA
# 2        AFR        NH         NH  FLU_NRT_AFR          DZA
# 3        AFR        NH         NH  FLU_NRT_AFR          DZA
# 4        AFR        NH         NH  FLU_NRT_AFR          DZA
# 5        AFR        NH         NH  FLU_NRT_AFR          DZA
# 6        AFR        NH         NH  FLU_NRT_AFR          DZA
# 7        AFR        NH         NH  FLU_NRT_AFR          DZA
# 8        AFR        NH         NH  FLU_NRT_AFR          DZA
# 9        AFR        SH         SH  FLU_STH_AFR          ZAF
# 10       AFR        SH         SH  FLU_STH_AFR          ZAF
# 11       AFR        SH         SH  FLU_STH_AFR          ZAF
# 12       AFR        SH         SH  FLU_STH_AFR          ZAF
# 13       AFR        SH         SH  FLU_STH_AFR          ZAF
# 14       AFR        SH         SH  FLU_STH_AFR          ZAF
# 15       AFR        SH         SH  FLU_STH_AFR          ZAF
# 16       AFR        SH         SH  FLU_STH_AFR          ZAF
# 17       AFR        SH         SH  FLU_STH_AFR          ZAF
# 18       AFR        SH         SH  FLU_STH_AFR          ZAF
# 19       AFR        SH         SH  FLU_STH_AFR          ZAF
#
#    COUNTRY_AREA_TERRITORY ISO_WEEKSTARTDATE  ISO_YEAR  ISO_WEEK   ISOYW  ...  \
# 0                 Algeria        2024-12-09      2024        50  202450  ...
# 1                 Algeria        2024-12-16      2024        51  202451  ...
# 2                 Algeria        2024-12-16      2024        51  202451  ...
# 3                 Algeria        2025-01-27      2025         5  202505  ...
# 4                 Algeria        2025-02-24      2025         9  202509  ...
# 5                 Algeria        2025-02-24      2025         9  202509  ...
# 6                 Algeria        2025-02-24      2025         9  202509  ...
# 7                 Algeria        2025-02-24      2025         9  202509  ...
# 8                 Algeria        2025-03-03      2025        10  202510  ...
# 9            South Africa        2016-01-04      2016         1  201601  ...
# 10           South Africa        2016-01-11      2016         2  201602  ...
# 11           South Africa        2016-01-11      2016         2  201602  ...
# 12           South Africa        2016-01-11      2016         2  201602  ...
# 13           South Africa        2016-01-25      2016         4  201604  ...
# 14           South Africa        2016-02-01      2016         5  201605  ...
# 15           South Africa        2016-02-08      2016         6  201606  ...
# 16           South Africa        2016-02-15      2016         7  201607  ...
# 17           South Africa        2016-02-15      2016         7  201607  ...
# 18           South Africa        2016-02-15      2016         7  201607  ...
# 19           South Africa        2016-02-29      2016         9  201609  ...
#
#    GEOSPREAD_COMMENTS  COMMENTS  ILI_NB_SITES  SARI_NB_SITES  ARI_NB_SITES  \
# 0                 NaN       NaN           NaN            NaN           NaN
# 1                 NaN       NaN           NaN            NaN           NaN
# 2                 NaN       NaN           NaN            NaN           NaN
# 3                 NaN       NaN           NaN            NaN           NaN
# 4                 NaN       NaN           NaN            NaN           NaN
# 5                 NaN       NaN           NaN            NaN           NaN
# 6                 NaN       NaN           NaN            NaN           NaN
# 7                 NaN       NaN           NaN            NaN           NaN
# 8                 NaN       NaN           NaN            NaN           NaN
# 9                 NaN       NaN           NaN            NaN           NaN
# 10                NaN       NaN           NaN            NaN           NaN
# 11                NaN       NaN           NaN            NaN           NaN
# 12                NaN       NaN           NaN            NaN           NaN
# 13                NaN       NaN           2.0            5.0           NaN
# 14                NaN       NaN           NaN            NaN           NaN
# 15                NaN       NaN           NaN            NaN           NaN
# 16                NaN       NaN           NaN            NaN           NaN
# 17                NaN       NaN           NaN            NaN           NaN
# 18                NaN       NaN           NaN            NaN           NaN
# 19                NaN       NaN           2.0            5.0           NaN
#
#     PNEU_NB_SITES  MMWR_WEEKSTARTDATE  MMWR_YEAR  MMWR_WEEK  MMWRYW
# 0             NaN          2024-12-08       2024         50  202450
# 1             NaN          2024-12-15       2024         51  202451
# 2             NaN          2024-12-15       2024         51  202451
# 3             NaN          2025-01-26       2025          5  202505
# 4             NaN          2025-02-23       2025          9  202509
# 5             NaN          2025-02-23       2025          9  202509
# 6             NaN          2025-02-23       2025          9  202509
# 7             NaN          2025-02-23       2025          9  202509
# 8             NaN          2025-03-02       2025         10  202510
# 9             NaN          2016-01-03       2016          1  201601
# 10            NaN          2016-01-10       2016          2  201602
# 11            NaN          2016-01-10       2016          2  201602
# 12            NaN          2016-01-10       2016          2  201602
# 13            NaN          2016-01-24       2016          4  201604
# 14            NaN          2016-01-31       2016          5  201605
# 15            NaN          2016-02-07       2016          6  201606
# 16            NaN          2016-02-14       2016          7  201607
# 17            NaN          2016-02-14       2016          7  201607
# 18            NaN          2016-02-14       2016          7  201607
# 19            NaN          2016-02-28       2016          9  201609
#
# [20 rows x 38 columns]

# %%
def piechartcol(targetcol : str):    
    # encode the categorical data
    categories = data[targetcol].unique()
    values = []
    catvalseries = data[targetcol].value_counts()
    
    for category in categories:
        values.append(catvalseries.get(category))
    
    def func(pct, allvals):
        absolute = int(np.round(pct/100.*np.sum(allvals)))
        return f"{pct:.1f}%\n({absolute:d})"
    
    print(categories)
    print(values[0])
    plt.pie(values, labels=categories, autopct=lambda pct: func(pct, values))

# %%
piechartcol("WHOREGION")
# Out:
# [202450 202451 202505 ... 200046 200051 200953]
# 781
