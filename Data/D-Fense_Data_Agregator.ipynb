# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import os 


print(os.listdir())
# Assign directory
directory = r"./D-FENSE/processed_data"
findf = pd.DataFrame()
# Iterate over files in directory
for name in os.listdir(directory):
    if name[-3:] == "csv":
        citycode = name[-6:-4]
        df = pd.read_csv(os.path.join(directory, name))
        df['region'] = citycode
        if len(findf) == 0:
            findf = df
        else:
            findf = pd.concat([findf, df])
        print("-----")
        #print(f.read())
findf = findf.sort_values('epiweek')
print(findf)


#df = pd.read_csv("D-FENSE/processed_data/.csv")
# Out:
# ['FID', 'D-FENSE', 'merged_d-fense.csv', 'DrivenData', 'README.md', 'D-Fense_Data_Agregator.ipynb', '.ipynb_checkpoints']
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
# -----
#      epiweek  cases   temp_min   temp_med   temp_max  precip_min  precip_med  \
# 0     201001   3539  21.658084  25.004341  29.274303    0.012281    0.302680
# 0     201001     22  24.048092  26.776109  30.772313    0.002407    0.082629
# 0     201001    208  23.877589  26.699426  30.751801    0.015402    0.285009
# 0     201001   4256  22.527846  25.419562  29.649180    0.021887    0.373958
# 0     201001    210  22.065314  25.423990  29.700304    0.003048    0.076435
# ..       ...    ...        ...        ...        ...         ...         ...
# 727   202352     17  24.224096  28.085244  33.075569    0.003993    0.053006
# ...

# %%
findf.to_csv('merged_d-fense.csv', index=False)

# %%
directory = r"./D-FENSE/processed_data"
# Iterate over files in directory
for name in os.listdir(directory):
    print(name)
    print(name[-6:-4])
# Out:
# DengueSprint2024_ProcessedData_SE.csv
# SE
# DengueSprint2024_ProcessedData_PA.csv
# PA
# DengueSprint2024_ProcessedData_RO.csv
# RO
# DengueSprint2024_ProcessedData_AM.csv
# AM
# DengueSprint2024_ProcessedData_RJ.csv
# RJ
# DengueSprint2024_ProcessedData_GO.csv
# GO
# README.md
# DM
# DengueSprint2024_ProcessedData_PE.csv
# PE
# DengueSprint2024_ProcessedData_BA.csv
# BA
# DengueSprint2024_ProcessedData_PI.csv
# PI
# DengueSprint2024_ProcessedData_DF.csv
# DF
# DengueSprint2024_ProcessedData_ES.csv
# ES
# DengueSprint2024_ProcessedData_CE.csv
# CE
# DengueSprint2024_ProcessedData_AP.csv
# AP
# DengueSprint2024_ProcessedData_MS.csv
# MS
# DengueSprint2024_ProcessedData_MT.csv
# MT
# DengueSprint2024_ProcessedData_SC.csv
# SC
# DengueSprint2024_ProcessedData_RN.csv
# RN
# DengueSprint2024_ProcessedData_PB.csv
# PB
# DengueSprint2024_ProcessedData_AC.csv
# AC
# DengueSprint2024_ProcessedData_PR.csv
# PR
# DengueSprint2024_ProcessedData_MG.csv
# MG
# ...
